# %%
from  django.db import models
 
 
class department(models.model):
    dept_id = models.AutoFiled(primary_key=True)
    dept_name = models.CharField(max_length =225 , unique =True)
    
    def __str__(self):
        return self.dept_name 
        
class Employee(models.model):
    id = models.AutoFiled(primary_key =True)
    name =models.CharField(max_length =225)
    salary =models.DecimalFiled(max_digit =10 decimal_places =2)
    address =models.TextField()
    department =models.ForeignKey(department, on_delete= models.CASCADE, 
    Related_name = "Employee"    )
    
    def __str__(self):
        return self.emp_name 
        
from app.models import employee 
employee = Employess.objects.all()
for emp in employee :
    print(emp.id, emp.emp_name, emp.emp_salary, emp.emp_address, emp.department.dept_name)


dept = Department.objects.get(dept_name ='IT')
emp =employee.objects.filter



from django.shortcuts import render 
from  app.models import Employess 

def emp_list(request):
    employee = Employess.objects.all()
    return render(request,'emp_list.html',{'employee : employee'})
    

<tr>
    <th> id </th>
    <th> Emp Name : </th>
    <th> Emp Salary : </th>
    <th> Emp address :</th>
    
    
</tr>

{% for emp in employee %}

<tr>
    <th> {{emp.id}}</th>
    <th> {{emp.}}</th>
    <th> {{}}</th>
    <th> {{}}</th>
    <th> {{emp.department.dept_name}}</th>
</tr>



from  rest_fromework import serializers
from  .models import Employess , Department 

class  Departmentserializers(serializers.modelSerializer):
    class meta :
        model = Department  
        fields = '__all__'
class EmployeeSerializer(serializers.ModelSerializer):
    department = DepartmentSerializer()
    
    class meta:
        model = Employess 
        fields = '__all__' 

from rest_fromework.decoraters import api_view
from rest_fromework.responsee import response
from .models import Employess 
form .serializers  import EmployeeSerializer, DepartmentSerializer 

        
@api_view(['GET'])
def emp_api(request):
    employee = Employess.objects.all()
    serializers =EmployeeSerializer(employee, many =True)
    return Response (serializers.data)

# %%
def tree_fun(hight):
    length = hight *2 -1 
    start = 1
    
    for i in range(1,hight+1):
        # print("*" * start).center(length)
        print(("*" * start).center(length))

        start +=2 
        
tree_fun(6)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
