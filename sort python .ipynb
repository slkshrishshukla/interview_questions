# %%
#  Quick Sort 
quickSort(arr,beg,end)
    if (beg<end)
        pivotindex =partition(arr,beg,end)
        quicksort(arr,beg,pivotindex-1)
        quicksort(arr,pivotindex_1,end)

# %%
# merge sort 
Merge sort (arr,left,right)
 if left >= right 
    mid =(left+right)/2
    mergeSort =(arr,mid+1 mid)
    mergesort =(arr,mid+1,right)
    mergeSort =(arr,left ,mid right)
end
