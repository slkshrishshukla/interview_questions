# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('EcomPur.csv')
print(df)
df.head()
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
df.isna().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.shape[0]
# Out:
# 10000

# %%
df.shape[1]
# Out:
# 14

# %% [markdown]
# Highest and Lowest Purchase Prices.
# List item
# List item

# %%
#Step:1 Retrive all the Column names
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Step:2 Retrive the Purchase Price Column
df['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
#Step:3 Finding the max Value of Purchase Price Column 
df['Purchase Price'].max()
# Out:
# np.float64(99.99)

# %%
#Step:1 Finding the mean of Purchase Column 
df['Purchase Price'].mean()
# Out:
# np.float64(50.347302)

# %%
#Step:1 Retrive all the Column names
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Step:2 Retrive the Language Column
df['Language']
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
#Step:3 Finding that which column contains 'fr'
df['Language']=='fr'   #gives boolean data
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Language, Length: 10000, dtype: bool

# %%
#Step:5 Finding the Number of people who speak 'fr'
len(df[df['Language']=='fr'])
# Out:
# 1097

# %%
#Step:1 Retrive all the Column names 
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Step:2 Retrive the Job Column
df['Job']
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object

# %%
#Step:3 Finding the given condition 
df['Job'].str.contains('engineer',case=False)   #Gives boolean data
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
#Step:4 Passing that boolean data to the Data frame Object
df[df['Job'].str.contains('engineer',case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
#Step:5 Getting only the job titles from the dataset 
df[df['Job'].str.contains('engineer',case=False)]['Job']
# Out:
# 1                         Drilling engineer
# 3                         Drilling engineer
# 50                      Mechanical engineer
# 55      Engineer, broadcasting (operations)
# 60                   Engineer, agricultural
#                        ...
# 9948                    Structural engineer
# 9952                       Engineer, energy
# 9970                    Electrical engineer
# 9977                    Biomedical engineer
# 9996                        Energy engineer
# Name: Job, Length: 984, dtype: object

# %%
#Step:6 Printing all the jobs that contain engineer word
for val in df[df['Job'].str.contains('engineer',case=False)]['Job']:
    print(val)
# Out:
# Drilling engineer
# Drilling engineer
# Mechanical engineer
# Engineer, broadcasting (operations)
# Engineer, agricultural
# Engineer, civil (consulting)
# Engineer, materials
# Engineer, land
# Engineer, water
# Technical sales engineer
# Engineer, aeronautical
# Engineering geologist
# Engineer, chemical
# Engineer, building services
# Energy engineer
# Water engineer
# Software engineer
# Engineer, civil (consulting)
# Engineer, civil (contracting)
# Structural engineer
# Mining engineer
# Engineer, energy
# Manufacturing systems engineer
# Control and instrumentation engineer
# Consulting civil engineer
# Engineer, structural
# Site engineer
# Engineer, building services
# Mining engineer
# Engineer, maintenance (IT)
# Consulting civil engineer
# Petroleum engineer
# Engineer, maintenance
# Communications engineer
# Energy engineer
# Civil engineer, consulting
# Engineer, production
# Mining engineer
# Engineer, energy
# Engineer, communications
# Engineer, drilling
# ...

# %%
#Step:1 Retrive all the Column names
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# Step:2 Find the Person who booked from the given IP address
df['IP Address']
df['IP Address']=='132.207.160.22'   #gives boolean data
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: IP Address, Length: 10000, dtype: bool

# %%
#Step:3 Pass that boolean data to the data frame to get the details 
df[df['IP Address']=='132.207.160.22']
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
#Step:4 Finding only the name of the person who booked from the given IP address 
df[df['IP Address']=='132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
# 11. How many People have Mastercard as their Credit Card Provider and made a purchase above 50?
#Step:1 Retrive all the columns names
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Step:2 Retrive the Colun Data we want to work 
df['CC Provider']
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
#Step:3 Find the Mastercard CC Provider 
df['CC Provider']=='Mastercard'     #gives boolean data
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Provider, Length: 10000, dtype: bool

# %%
#Step:4 Passing that boolean array to dataframe to Retrive the Row details
df[df['CC Provider']=='Mastercard']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 41    779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
# ...                                                 ...    ...      ...
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
#Step:5 Finding the data that who is having CC Provider as mastercard and having purchase greater than 50 
df[df['CC Provider']=='Mastercard']['Purchase Price']>50
# Out:
# 1        True
# 18       True
# 31       True
# 35       True
# 41      False
#         ...
# 9947    False
# 9948     True
# 9954     True
# 9981     True
# 9987     True
# Name: Purchase Price, Length: 816, dtype: bool

# %%
#Step:5 Finding the number who is having CC Provider as mastercard and having purchase greater than 50 
len(df[df['CC Provider']=='Mastercard']['Purchase Price']>50)
# Out:
# 816

# %%
# 12. Find the email of the person with the following Credit Card Number: 4664825258997302  
#Step:1 Retrive all the columns names
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Step:2 Retriving the column that we have to work 
df['Credit Card']
# Out:
# 0       6011929061123406
# 1       3337758169645356
# 2           675957666125
# 3       6011578504430710
# 4       6011456623207998
#               ...
# 9995     342945015358701
# 9996     210033169205009
# 9997    6011539787356311
# 9998     180003348082930
# 9999    4139972901927273
# Name: Credit Card, Length: 10000, dtype: int64

# %%
# df['Credit Card'] == 4664825258997302 
df['Credit Card']== 4664825258997302      #Gives boolean array
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 9995    True
# 9996    True
# 9997    True
# 9998    True
# 9999    True
# Name: Credit Card, Length: 10000, dtype: bool

# %%
#step:4 Pass That boolean array to the data frame to get the related row 
df[df['Credit Card'] == 4664825258997302]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
#Step:5 Find the Email only in the column
df[df['Credit Card'] == 4664825258997302]['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
#Step:1 Retrive all the Column Names
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Step:2 Retriving the column that we have to work 
df['AM or PM']
# Out:
# 0       PM
# 1       PM
# 2       PM
# 3       PM
# 4       AM
#         ..
# 9995    PM
# 9996    AM
# 9997    AM
# 9998    PM
# 9999    AM
# Name: AM or PM, Length: 10000, dtype: object

# %%
#Step:3 Finding the Number of AM orders  and the PM orders
df['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
#Step:1 Retrive all the Column Names
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Step:2 Retrive the Column that we want to work 
df['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
#Step:3 Creating a function to find the exp year of Credit Card
def findexp():
    cnt=0
    for date in df['CC Exp Date']:
        if date.split('-')[1]=='20':
            cnt=cnt + 1
    return cnt

# %%
#Step:4 Finding the Number of people that having their Credit card expiry in 2020
print('Number of people having their Credit card expiry in 2020:',findexp())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 2
#       1 #Step:4 Finding the Number of people that having their Credit card expiry in 2020
# ----> 2 print('Number of people having their Credit card expiry in 2020:',findexp())
#
# Cell In[58], line 5, in findexp()
#       3 cnt=0
#       4 for date in df['CC Exp Date']:
# ----> 5     if date.split('-')[1]=='20':
#       6         cnt=cnt + 1
#       7 return cnt
#
# IndexError: list index out of range

# %%
from  django.db import models 
from django.contrib.auth.models import User 

class Account(models.Model):
    user = models.OneToOneField(User, on_delete=models.CASCADE)
    balance =models.DecimalField(max_digits=10,decimal_places=2,default=0.00)

class Transactions(models.Model):
    Account = models.ForeignKey(Account,on_delete=models.CASCADE)
    transactions_type = models.CharField(max_length=10,choices=[('credit', 'Credit'), ('debit', 'Debit')])
    amount =models.DecimalField(max_length=10,decimal_places = 2)
    timestamp = models.DateTimeField(auto_now_add = True)

# %%
# serializer.py
from rest_framework import serializers 
from .models import Account,Transactions 

class AccountSerializer(serializers.ModelSerializer):
    class meta:
        model = Account 
        fields ='__all__'
    class TransactionsSerializer(serializers.ModelSerializer):
        class meta:
            model = Transactions 
            fields  ='__all__'

# %%
# views.py
from rest_framework import viewsets
from .models import Account, Transactions 
from .serializers import AccountSerializer, TransactionsSerializer 

class AccountViewSet(viewsets.ModelViewSet):
    queryset = Account.objects.all()
    serializer_class = AccountSerializer

class TransactionViewSet(viewsets.ModelViewSet):
    queryset =Transactions.objects.all()
    serializer_class = TransactionsSerializer

# %%
# atomic.py
from django.db import transaction
from rest_framework.response import Response
from rest_framework.decorators import api_view
from .models import Account, Transaction


@api_view(['POST'])
def process_transaction(request):
    account_id =request.data.get('account_id')
    transaction_type  = request.data.get('transaction_type')
    amount = request.data.get('amount')
    try :
        with transaction.atomic():
            account =Account.objects.get(id =account_id)
            if  transaction_type =='debit' and account.balance <float(amount):
                return Response ({'error' :'insufficient Balance'}, status =400)
            if transaction_type == 'debit':
                account.balance -= float(amount)
            else:
                account.balance += float(amount)
            account.save()
            Transaction.objects.create(account=account,transaction_type =transaction_type,amount = amount) 

        return Response({'massage':'Transaction successful'})
    except Exception as e :
        return Response({'error': str(e)}, status = 500 )

# %%
from rest_framework.permissions import IsAuthenticated

class TransactionViewSet
