# %%
import unittest 
from main import Calculator 

class TestCalc(unittest.TestCase):
    def setUp(self):
        "set up an instance each text"
        self.Calcualator()
    
    def test_add(self):
        result =self.calc.add(6,6) # 12
        self.assertEqual(result, 12)

    def tearDown(self):
        'any cleanup'
        pass

# %%
input_str = "aaabbbccaaadd"

res = [] 
count = 1 

for i in range(1,len(input_str)):
    if input_str[i] == input_str[i - 1]:
        count += 1
    else:
        res.append(s[i -1]) + str(count)
        count = 1
res.append(s[-1] + str(count)) 

''.join(res)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 l1 = [0,0, 1, 3, 12, 0, 0]
#       2 for i in l1:
# ----> 3     if l1[i] == '0':
#       4         l1.remove(i)
#       5         l1.append(i)
#
# IndexError: list index out of range
